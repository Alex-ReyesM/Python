# %%
#Python Dia 1

# %%
#Enteros o Integers

# %%
#Flotantes o números con decimales

# %%
#Strings (palabras)

# %%
#Booleanos (Verdadero o falso)

# %%
#Print (Imprimir)
#Input (Llena el blanco)
#Operaciones básicas
#Exponente **
#División con redondeo, siempre redondea para abajo //
